# %%
# !pip install docling
# Out:
# Collecting docling
#   Downloading docling-2.14.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from docling) (4.12.3)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.10/dist-packages (from docling) (2024.12.14)
# Collecting deepsearch-glm<2.0.0,>=1.0.0 (from docling)
#   Downloading deepsearch_glm-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting docling-core<3.0.0,>=2.12.1 (from docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading docling_core-2.12.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting docling-ibm-models<4.0.0,>=3.1.0 (from docling)
#   Downloading docling_ibm_models-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting docling-parse<4.0.0,>=3.0.0 (from docling)
#   Downloading docling_parse-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting easyocr<2.0,>=1.7 (from docling)
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /usr/local/lib/python3.10/dist-packages (from docling) (0.27.0)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from docling) (5.3.0)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.1.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.10/dist-packages (from docling) (3.1.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from docling) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from docling) (2.10.3)
# Collecting pydantic-settings<3.0.0,>=2.3.0 (from docling)
#   Downloading pydantic_settings-2.7.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pypdfium2<5.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.6 MB/s eta 0:00:00
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from docling) (2.32.3)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from docling) (1.13.1)
# Collecting typer<0.13.0,>=0.12.5 (from docling)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.6)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (4.23.0)
# Collecting pillow<11.0.0,>=10.3.0 (from docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (6.0.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (4.12.2)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from docling-core[chunking]<3.0.0,>=2.12.1->docling) (4.47.0)
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models<4.0.0,>=3.1.0->docling)
#   Downloading jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<4.0.0,>=3.1.0->docling) (1.26.4)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<4.0.0,>=3.1.0->docling) (4.10.0.84)
# Requirement already satisfied: safetensors<1,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from safetensors[torch]<1,>=0.4.3->docling-ibm-models<4.0.0,>=3.1.0->docling) (0.4.5)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<4.0.0,>=3.1.0->docling) (2.5.1+cu121)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<4.0.0,>=3.1.0->docling) (0.20.1+cu121)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<4.0.0,>=3.1.0->docling) (4.67.1)
# Collecting autoflake<3.0.0,>=2.3.1 (from docling-parse<4.0.0,>=3.0.0->docling)
#   Downloading autoflake-2.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (0.25.0)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling)
#   Downloading python_bidi-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (2.0.6)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling)
#   Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling)
#   Downloading ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (24.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.27.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.3.0->docling)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->docling) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->docling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->docling) (2.2.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->docling) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->docling) (13.9.4)
# Collecting pyflakes>=3.0.0 (from autoflake<3.0.0,>=2.3.1->docling-parse<4.0.0,>=3.0.0->docling)
#   Downloading pyflakes-3.2.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoflake<3.0.0,>=2.3.1->docling-parse<4.0.0,>=3.0.0->docling) (2.2.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<4.0.0,>=3.1.0->docling) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.12.1->docling-core[chunking]<3.0.0,>=2.12.1->docling) (0.22.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (2.18.0)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.1.0->docling) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.1.0->docling) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.1.0->docling) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.1.0->docling) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.12.1->docling) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.12.1->docling) (0.21.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.1.0->docling) (3.0.2)
# Collecting multiprocess (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Collecting dill>=0.3.9 (from multiprocess->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.12.1->docling)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading docling-2.14.0-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.1/113.1 kB 4.3 MB/s eta 0:00:00
# Downloading deepsearch_glm-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.4 MB/s eta 0:00:00
# Downloading docling_core-2.12.1-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 kB 5.4 MB/s eta 0:00:00
# Downloading docling_ibm_models-3.1.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.5 MB/s eta 0:00:00
# Downloading docling_parse-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 71.6 MB/s eta 0:00:00
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 77.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading marko-2.1.2-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.0-py3-none-any.whl (29 kB)
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 65.0 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 15.0 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 26.8 MB/s eta 0:00:00
# Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 24.2 MB/s eta 0:00:00
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.8 MB/s eta 0:00:00
# Downloading autoflake-2.3.1-py3-none-any.whl (32 kB)
# Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 32.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 10.7 MB/s eta 0:00:00
# Downloading ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 25.0 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 38.4 MB/s eta 0:00:00
# Downloading python_bidi-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.8/286.8 kB 17.5 MB/s eta 0:00:00
# Downloading pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 14.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.3 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: python-bidi, pyclipper, filetype, XlsxWriter, rtree, python-dotenv, python-docx, pypdfium2, pyflakes, pillow, ninja, mpire, marko, jsonref, jsonlines, dill, deepsearch-glm, python-pptx, multiprocess, autoflake, typer, pydantic-settings, docling-parse, semchunk, easyocr, docling-core, docling-ibm-models, docling
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.1
#     Uninstalling typer-0.15.1:
#       Successfully uninstalled typer-0.15.1
# Successfully installed XlsxWriter-3.2.0 autoflake-2.3.1 deepsearch-glm-1.0.0 dill-0.3.9 docling-2.14.0 docling-core-2.12.1 docling-ibm-models-3.1.0 docling-parse-3.0.0 easyocr-1.7.2 filetype-1.2.0 jsonlines-3.1.0 jsonref-1.1.0 marko-2.1.2 mpire-2.10.2 multiprocess-0.70.17 ninja-1.11.1.3 pillow-10.4.0 pyclipper-1.3.0.post6 pydantic-settings-2.7.0 pyflakes-3.2.0 pypdfium2-4.30.0 python-bidi-0.6.3 python-docx-1.1.2 python-dotenv-1.0.1 python-pptx-1.0.2 rtree-1.3.0 semchunk-2.2.2 typer-0.12.5

# %% [markdown]
# # OCR + Layout Detection

# %%
from docling.datamodel.base_models import InputFormat
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions, TableFormerMode
from docling.pipeline.standard_pdf_pipeline import StandardPdfPipeline
from docling.datamodel.pipeline_options import (
    EasyOcrOptions,
    OcrMacOptions,
    PdfPipelineOptions,
    RapidOcrOptions,
    TesseractCliOcrOptions,
    TesseractOcrOptions,
)

# to explicitly prefetch:
artifacts_path = StandardPdfPipeline.download_models_hf()

ocr_options = EasyOcrOptions(lang=['ru', 'en'])

pipeline_options = PdfPipelineOptions(do_table_structure=True, artifacts_path=artifacts_path)
pipeline_options.table_structure_options.mode = TableFormerMode.ACCURATE  # use more accurate TableFormer model
pipeline_options.table_structure_options.do_cell_matching = True
pipeline_options.images_scale = 1.0
pipeline_options.generate_page_images = True
pipeline_options.generate_picture_images = True
pipeline_options.ocr_options = ocr_options

doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from docling.datamodel.document import ConversionResult

conv_result: ConversionResult = doc_converter.convert("manual.pdf") # previously `convert_single`
# Out:
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.

# %%
import cv2
import numpy as np

# def get_thickness(img):
#     i = 0
#     while img.any():
#         i += 1
#         img = cv2.erode(img, kernel=np.ones((3, 3)))
#     return i

def get_thickness(binary):
    width = (binary > 128).sum(1)
    count = (np.diff(binary, axis=1) > 128).sum(1)
    thickness = width[count > 0] / count[count > 0]
    return np.median(thickness[~np.isnan(thickness)])


def get_font_style(image, min_char_area=10):
    gray = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)

    _, binary = cv2.threshold(gray.copy(), 128, 255, cv2.THRESH_BINARY_INV)
    contours, _ = cv2.findContours(binary.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    bounding_boxes = [cv2.boundingRect(contour) for contour in contours]

    bounding_boxes = [bbox for bbox in bounding_boxes if bbox[2] * bbox[3] > min_char_area]

    heights = [bbox[3] for bbox in bounding_boxes]
    if len(heights) > 1:
        fontsize = np.quantile(heights, 0.5)
        thickness = get_thickness(binary)
    else:
        fontsize = None
        thickness = None
    return fontsize, thickness

# %%
CAPTION = "caption"
FOOTNOTE = "footnote"
FORMULA = "formula"
LIST_ITEM = "list_item"
PAGE_FOOTER = "page_footer"
PAGE_HEADER = "page_header"
PICTURE = "picture"
SECTION_HEADER = "section_header"
TABLE = "table"
TEXT = "text"
TITLE = "title"
DOCUMENT_INDEX = "document_index"
CODE = "code"
CHECKBOX_SELECTED = "checkbox_selected"
CHECKBOX_UNSELECTED = "checkbox_unselected"
FORM = "form"
KEY_VALUE_REGION = "key_value_region"

# %%
from pathlib import Path
# import pandas as pd
from docling_core.types.doc.document import (
    TextItem, PictureItem, SectionHeaderItem, TableItem, ListItem)
from PIL import Image, ImageDraw


def draw_bbox(image_pth, bbox, title):
    color = 'blue'
    if title in [SECTION_HEADER, TITLE]:
        color = 'green'
    elif title in [TABLE, PICTURE]:
        color = 'red'
    elif title == CAPTION:
        color = 'orange'
    # draw boxes
    image = Image.open(image_pth)
    draw = ImageDraw.Draw(image)
    x1, y1, x2, y2 = bbox.l, image.size[1] - bbox.t, bbox.r, image.size[1] - bbox.b
    draw.rectangle((x1, y1, x2, y2), outline=color, width=2)
    draw.text((x1, y1), title, fill="red")
    image.save(image_pth)


images_dir = Path("images")
images_dir.mkdir(parents=True, exist_ok=True)

pages_dir = Path("pages")
pages_dir.mkdir(parents=True, exist_ok=True)

# Save page images
for page_no, page in conv_result.document.pages.items():
    page_no = page.page_no
    page_image_filename = pages_dir / f"{page_no}.png"
    with page_image_filename.open("wb") as fp:
        page.image.pil_image.save(fp, format="PNG")


picture_counter = 0
annotations = []
idx = 1
## Iterate the elements in reading order, including hierachy level:
for item, level in conv_result.document.iterate_items():
    if item.label in [PAGE_FOOTER, PAGE_HEADER]:
        continue
    prov_item = item.prov[0]
    # draw_bbox(pages_dir / f"{prov_item.page_no}.png", prov_item.bbox, item.label.lower())
    # print(level, type(item))
    image_pth = pages_dir / f"{prov_item.page_no}.png"
    bbox = prov_item.bbox
    image = Image.open(image_pth)
    x1, y1, x2, y2 = bbox.l, image.size[1] - bbox.t, bbox.r, image.size[1] - bbox.b
    item_image = image.crop((x1, y1, x2, y2))
    item_data = {
        'id': idx,
        'bbox': [(x1 + x2) / 2, (y1 + y2) / 2, x2 - x1, y2 - y1],
        'page': prov_item.page_no
    }
    if not all(item_image.size):
        continue
    if isinstance(item, TextItem):
        print(item.text)
        fontsize, thickness = get_font_style(item_image, min_char_area=10)
        # print(f"Estimated font size: {fontsize}")
        # print(f"Estimated thickness: {thickness}")
        content = {
            'text': item.text,
            'type': 'h' if item.label.lower() in [SECTION_HEADER, TITLE] else 'p',
            'fontsize': fontsize,
            'thickness': thickness
        }
    elif isinstance(item, TableItem) and not isinstance(item, ListItem):
        # table_df: pd.DataFrame = item.export_to_dataframe()
        # print(table_df.to_markdown())
        # print(item.export_to_html())
        content = {
            'html': item.export_to_html(),
            'type': 'table'
        }
    elif isinstance(item, PictureItem):
        picture_counter += 1
        element_image_filename = images_dir / f"picture-{picture_counter}.png"
        with element_image_filename.open("wb") as fp:
            item.get_image(conv_result.document).save(fp, "PNG")
        content = {
            'src': str(element_image_filename),
            'type': 'img'
        }
    elif isinstance(item, ListItem):
        # print(item.export_to_html())
        content = {
            'text': item.text,
            'type': 'li',
            'fontsize': fontsize,
            'thickness': thickness
        }
    item_data.update(content)
    annotations.append(item_data)
    idx += 1
# Out:
# КриптоПро PDF
# Estimated font size: 25.0
# Estimated thickness: 5.459595959595959
# ВЕРСИЯ 1.6
# Estimated font size: 11.0
# Estimated thickness: 2.6948051948051948
# Руководство по эксплуатации
# Estimated font size: 10.0
# Estimated thickness: 2.475
# АННОТАЦИЯ
# Estimated font size: 10.0
# Estimated thickness: 1.8666666666666667
# Настоящий документ содержит описание процесса установки и инструкции по использованию модуля создания и проверки электронной подписи «КриптоПро PDF» в программах Adobe Reader и Adobe Acrobat.
# Estimated font size: 5.0
# Estimated thickness: 1.3333333333333333
# «КриптоПро PDF» представляет собой средство создания и проверки электронной подписи  для  файлов  в  формате  PDF,  предназначенное  для  использования  совместно  со  средством криптографической защиты информации КриптоПро CSP.
# Estimated font size: 6.0
# Estimated thickness: 1.275
# Информация о разработчике «КриптоПро PDF»:
# Estimated font size: 6.0
# Estimated thickness: 2.7122015915119366
# ООО «Крипто-Про»
# Estimated font size: 7.0
# Estimated thickness: 1.2
# 127 018, Москва, а/я Крипто-Про
# Estimated font size: 6.0
# Estimated thickness: 1.3333333333333333
# Телефон: +7 495 995-48-20
# Estimated font size: 8.0
# Estimated thickness: 1.3846153846153846
# Факс: +7 495 995-48-20
# Estimated font size: 7.0
# Estimated thickness: 1.445012787723785
# http://www.CryptoPro.ru
# Estimated font size: None
# Estimated thickness: None
# E-mail: info@CryptoPro.ru
# Estimated font size: 6.0
# Estimated thickness: 1.2701612903225805
# СОДЕРЖАНИЕ
# Estimated font size: 10.0
# Estimated thickness: 1.9375
# <table><tbody><tr><td>1.</td><td>Требования к программному обеспечению ..................................................... 4</td></tr><tr><td>2.</td><td>Установка «КриптоПро PDF» ........................................................................... 5</td></tr><tr><td>3.</td><td>Эксплуатация «КриптоПро PDF» ................................................................... 10</td></tr><tr><td>3.1.</td><td>Настройка формирования и проверки ЭП в программе Adobe Acrobat ............. 10</td></tr><tr><td>3.2.</td><td>Ввод серийного номера лицензии «КриптоПро PDF» ...................................... 11</td></tr><tr><td>3.3.</td><td>Выбор языка плагина .................................................................................. 13</td></tr><tr><td>3.4.</td><td>Формирование ЭП ....................................................................................... 13</td></tr><tr><td>3.5.</td><td>Виды подписей в программах Adobe. ............................................................ 17</td></tr><tr><td>3.6.</td><td>Отличия Adobe Reader и Adobe Acrobat при создании ЭП. .............................. 17</td></tr><tr><td>3.7.</td><td>Создание ЭП в Adobe Reader ........................................................................ 18</td></tr><tr><td>3.8.</td><td>Проверка ЭП ............................................................................................... 20</td></tr><tr><td>4.</td><td>Перечень сокращений .................................................................................... 23</td></tr><tr><td>5.</td><td>Перечень рисунков ......................................................................................... 24</td></tr><tr><td>6.</td><td>Перечень таблиц ............................................................................................ 25</td></tr></tbody></table>
# 1. Требования к программному обеспечению
# Estimated font size: 9.0
# Estimated thickness: 1.75
# «КриптоПро PDF» предназначен для функционирования в следующих ОС:
# Estimated font size: 6.0
# Estimated thickness: 1.2475247524752475
# Microsoft Windows XP всех вариантов исполнения, как англоязычных, так и локализованных, с установленным пакетом обновления Service Pack 3 и выше;
# Estimated font size: 6.0
# Estimated thickness: 1.3632478632478633
# Microsoft Windows Server 2003 всех вариантов исполнения, как англоязычных, так и локализованных, с установленным пакетом обновления Service Pack 2 и выше;
# Estimated font size: 5.0
# Estimated thickness: 1.3333333333333333
# Microsoft Windows Vista, как англоязычных, так и локализованных, с установленным пакетом обновления Service Pack 2 и выше;
# Estimated font size: 6.0
# Estimated thickness: 1.2613636363636362
# Microsoft Windows Server 2008 всех вариантов исполнения, как англоязычных, так и локализованных, с установленным пакетом обновления Service Pack 2 и выше;
# Estimated font size: 6.0
# Estimated thickness: 1.282075178626903
# Microsoft Windows 7, как англоязычной, так и локализованной, с установленным пакетом обновления Service Pack 1 и выше;
# Estimated font size: 5.0
# Estimated thickness: 1.2590686274509804
# Microsoft Windows Server 2008 R2 всех вариантов исполнения, как англоязычных, так и локализованных, с установленным пакетом обновления Service Pack 1 и выше
# Estimated font size: 6.0
# Estimated thickness: 1.3333333333333333
# Microsoft Windows 8 всех вариантов исполнения, как англоязычных, так и локализованных;
# Estimated font size: 6.0
# Estimated thickness: 1.311965811965812
# Microsoft Windows 8.1 всех вариантов исполнения, как англоязычных, так и локализованных;
# Estimated font size: 5.0
# Estimated thickness: 1.2363636363636363
# Microsoft Windows Server 2012, как англоязычной, так и локализованной;
# Estimated font size: 6.0
# Estimated thickness: 1.3478260869565217
# Microsoft Windows Server 2012 R2, как англоязычной, так и локализованной.
# Estimated font size: 5.0
# Estimated thickness: 1.3476417594064654
# Для функционирования «КриптоПро PDF» должно быть установлено средство криптографической защиты информации КриптоПро CSP версии 3.6 или выше.
# Estimated font size: 6.0
# Estimated thickness: 1.2922824302134648
# Модуль «КриптоПро PDF» расширяет возможности программ Adobe Acrobat и Adobe Reader в части создания и проверки ЭП по алгоритму ГОСТ Р 34.10-2001.
# Estimated font size: 6.0
# Estimated thickness: 1.299498746867168
# Для функционирования «КриптоПро PDF» предварительно должна быть установлена одна из следующих программ:
# Estimated font size: 5.0
# Estimated thickness: 1.2487179487179487
# Adobe Acrobat версии 8, 9, Х или XI всех вариантов исполнения;
# Estimated font size: 6.0
# Estimated thickness: 1.3625
# Adobe Reader версии 8, 9, Х или XI.
# Estimated font size: 6.0
# Estimated thickness: 1.3846153846153846
# «КриптоПро  PDF»  поддерживает  полноценную  работу  в  защищенном  режиме Adobe Reader в версии 10.0.1 и выше.
# Estimated font size: 6.0
# Estimated thickness: 1.4
# 2. Установка «КриптоПро PDF»
# Estimated font size: 9.0
# Estimated thickness: 1.75
# Запустите установку пакета cppdf.msi , расположенного на компакт-диске. После коротких подготовительных процедур на экране появится окно мастера установки (см. Рисунок 1). Нажмите кнопку Далее .
# Estimated font size: 5.0
# Estimated thickness: 1.660919540229885
# Рисунок 1. Мастер установки «КриптоПро PDF»
# Estimated font size: 5.0
# Estimated thickness: 2.7142857142857144
# В следующем окне мастера установки ознакомьтесь с лицензионным соглашением на использование  «КриптоПро  PDF».  Если  Вы  согласны  со  всеми  пунктами  соглашения,  выделите пункт Я принимаю условия лицензионного соглашения , и нажмите Далее (см. Рисунок 2).
# Estimated font size: 5.0
# Estimated thickness: 1.5555555555555556
# Рисунок 2. Лицензионное соглашение на использование «КриптоПро PDF»
# Estimated font size: 6.0
# Estimated thickness: 2.268683675773312
# Следующим шагом необходимо ввести информацию о пользователе, производящем установку, и серийный номер лицензии на использование «КриптоПро PDF» (см. Рисунок 3). Поле серийного номера можно оставить пустым, тогда продукт будет работать в демонстрационном режиме в течение 30 дней.
# Estimated font size: 6.0
# Estimated thickness: 1.282258064516129
# Рисунок 3. Сведения о пользователе «КриптоПро PDF»
# Estimated font size: 5.0
# Estimated thickness: 2.357142857142857
# После нажатия на кнопку Далее программа установки отобразит диалоговое окно (см. Рисунок 4), где необходимо выбрать вид установки. «КриптоПро PDF» определяет два вида установки: полная и выборочная.
# Estimated font size: 6.0
# Estimated thickness: 1.3150387596899225
# Использование выборочной установки позволяет выбрать версии Adobe Acrobat и Adobe Reader, для которых будет установлен модуль «КриптоПро PDF» (см. Рисунок 5). Если при использовании выборочной установки не будет выбрана ни одна версия Adobe Acrobat или Adobe Reader, продолжить установку будет невозможно.
# Estimated font size: 6.0
# Estimated thickness: 1.332080200501253
# Рисунок 4. Вид установки «КриптоПро PDF»
# Estimated font size: 6.0
# Estimated thickness: 2.6862745098039214
# Рисунок 5. Выборочная установка «КриптоПро PDF»
# Estimated font size: 6.0
# Estimated thickness: 2.5134615384615384
# Следующее окно мастера служит для подтверждения установки (см. Рисунок 6). При необходимости можно вернуться назад и переопределить параметры установки. Для подтверждения нажмите кнопку Установить .
# Estimated font size: 6.0
# Estimated thickness: 1.6740953221535746
# Рисунок 6. Окно подтверждения установки «КриптоПро PDF»
# Estimated font size: 6.0
# Estimated thickness: 2.6180124223602483
# После выполнения всех описанных шагов мастер произведет установку КриптоПро PDF, сопровождая действия комментариями. По окончании установки мастер показывает окно с подтверждением успешной установки, где необходимо нажать кнопку Готово (см. Рисунок 7).
# Estimated font size: 6.0
# Estimated thickness: 1.4375
# Рисунок 7. Завершение работы мастера установки
# Estimated font size: 5.0
# Estimated thickness: 2.1666666666666665
# 3. Эксплуатация «КриптоПро PDF»
# Estimated font size: 9.0
# Estimated thickness: 1.7222222222222223
# 3.1. Настройка формирования и проверки ЭП в программе Adobe Acrobat
# Estimated font size: 7.0
# Estimated thickness: 1.5816326530612246
# Настроить формирование и проверку ЭП можно в окне «Digital Signatures Advanced Preferences», которое открывается через меню Edit Preferences Signatures (см. Рисунок 8).
# Estimated font size: 5.0
# Estimated thickness: 1.6105006105006106
# Рисунок 8. Настройка формирования и проверки ЭП 1
# Estimated font size: 6.0
# Estimated thickness: 2.2027027027027026
# В открывшемся окне на закладке Creation следует  назначить метод создания подписи по умолчанию (см. Рисунок 9). При выборе методом по умолчанию CryptoPro PDF указанный метод будет использоваться для создания всех ЭП, добавляемых в документ. Если же был указан параметр Ask when I sign , то для каждой вновь создаваемой подписи будет выведено окно с возможностью выбора метода формирования данной ЭП.
# Estimated font size: 6.0
# Estimated thickness: 1.4428879310344827
# 1 Далее все рисунки интерфейса ЭП будут представлены для Adobe Acrobat версии XI. Для других версий Adobe Acrobat возможно незначительное отличие в интерфейсе.
# Estimated font size: 6.0
# Estimated thickness: 1.2913309252570158
# Рисунок 9. Настройки формирования ЭП
# Estimated font size: 6.0
# Estimated thickness: 2.653026427962489
# 3.2. Ввод серийного номера лицензии «КриптоПро PDF»
# Estimated font size: 7.0
# Estimated thickness: 1.4835953520164047
# При  установке  КриптоПро  PDF  без  ввода  лицензии  пользователю  предоставляется  лицензия с ограниченным сроком действия. Для использования КриптоПро PDF после окончания этого срока пользователь должен ввести серийный номер с бланка Лицензии, полученной у организации-разработчика или организации, имеющей права распространения продукта.
# Estimated font size: 6.0
# Estimated thickness: 1.2942307692307693
# При использовании КриптоПро PDF в Adobe Reader электронные подписи будут создаваться и проверяться без лицензии.
# Estimated font size: 6.0
# Estimated thickness: 1.2512512512512513
# Для  ввода  серийного  номера  лицензии  следует  выбрать  пункт  меню Help About Third-Party Plug-Ins CryptoProPDF . В окне информации о КриптоПро PDF (см. Рисунок 10) нажмите кнопку Установить лицензию.
# Estimated font size: 6.0
# Estimated thickness: 1.875
# Рисунок 10. Панель настройки
# Estimated font size: 6.0
# Estimated thickness: 2.57325746799431
# Система отобразит окно Сведения о пользователе , в котором необходимо указать сведения о пользователе, организации, а также ввести Серийный номер с бланка лицензии в соответствующие поля ввода (см. Рисунок 11).
# Estimated font size: 6.0
# Estimated thickness: 1.584090909090909
# Рисунок 11. Ввод серийного номера лицензии КриптоПро PDF
# Estimated font size: 6.0
# Estimated thickness: 2.681003223207091
# После ввода и нажатия клавиши ОК произойдет возврат к контрольной панели с указанным типом лицензии и сроком ее действия.
# Estimated font size: 6.0
# Estimated thickness: 1.3736468500443655
# 3.3. Выбор языка плагина
# Estimated font size: 7.0
# Estimated thickness: 1.4787775891341255
# Для настройки языка плагина следует выбрать пункт меню Help About Third-Party Plug-Ins CryptoProPDF . В  окне  информации о КриптоПро PDF (см. Рисунок 10) выберите язык: русский или английский.
# Estimated font size: 5.0
# Estimated thickness: 1.6153846153846154
# 3.4. Формирование ЭП
# Estimated font size: 7.0
# Estimated thickness: 1.8018518518518518
# Далее представлен стандартный сценарий формирования видимой 1 ЭП:
# Estimated font size: 6.0
# Estimated thickness: 1.3312790462719741
# Выберите  пункт  меню Подписание  Работа с сертификатами и    необходимый  тип подписи (см. Рисунок 12).
# Estimated font size: 6.0
# Estimated thickness: 1.7102803738317758
# Рисунок 12. Добавление ЭП
# Estimated font size: 5.0
# Estimated thickness: 2.6
# После этого, если при выборе метода создания ЭП по умолчанию был указан параметр Ask when I sign , будет предоставлено окно для выбора метода формирования ЭП. В этом случае необходимо выбрать метод CryptoPro PDF (см. Рисунок 13). Если же в настройках (см. п. 3.1) был назначен метод создания ЭП по умолчанию, то окно для выбора предоставлено не будет, а указанный метод будет использоваться автоматически.
# Estimated font size: 6.0
# Estimated thickness: 1.3479902713773682
# Рисунок 13. Выбор метода создания ЭП
# Estimated font size: 6.0
# Estimated thickness: 2.3573232323232323
# 1 Видимая ЭП отображается в документе и может быть отображена на печати. Невидимая ЭП не отображается в документе и представляется как метаданные.
# Estimated font size: 6.0
# Estimated thickness: 1.3333333333333333
# На следующем шаге в документе следует выделить область для отображения ЭП. После чего  в  появившемся  окне Select  a  certificate ( Выберите  сертификат )  будет  представлен список сертификатов, имеющихся в стандартном хранилище сертификатов Windows (см. Рисунок 14). Для удобства работы список сертификатов можно отсортировать по каждой графе, нажав на соответствующее название Subject ( Субъект ), Issuer ( Издатель ), Valid from ( Действителен с ) или Valid to ( Действителен по ).
# Estimated font size: 6.0
# Estimated thickness: 1.6714285714285713
# При выборе сертификата для создания ЭП будут доступны только сертификаты с  ключами по алгоритму ГОСТ Р 34.10-2001. КриптоПро PDF не предназначен для работы с сертификатами, основанными на других криптографических алгоритмах.
# Estimated font size: 6.0
# Estimated thickness: 1.332355816226784
# Просмотреть  свойства  выбранного  сертификата  можно  нажав  на  кнопку Show Certificate ( Показать сертификат ).
# Estimated font size: 6.0
# Estimated thickness: 1.828125
# Рисунок 14. Выбор сертификата для формирования ЭП
# Estimated font size: 6.0
# Estimated thickness: 2.451044776119403
# Для  использования  усовершенствованной  ЭП  следует  отметить  пункт To  use  an  CMS Advanced Electronic Signatures (CAdES) ( Усовершенствованная ЭП ). В этом случае ЭП будет  создаваться  в  соответствии  со  стандартом  CAdES  ("CMS  Advanced  Electronic  Signatures", ETSI Standard, RTS/ESI-000040, TS 101 733).
# Estimated font size: 6.0
# Estimated thickness: 1.5833333333333333
# Для создания усовершенствованной подписи необходимо указать адрес службы штампов времени. Для этого следует нажать кнопку Edit TSP Service ( Изменить службу TSP ) (см. Рисунок  15).  В  случае  если  служба  TSP  требует  аутентификации,  соответствующие  параметры также можно задать в окне настройки параметров соединения со службой штампов времени.
# Estimated font size: 5.0
# Estimated thickness: 1.4047244094488187
# Рисунок 15. Выбор и редактирование служб штампов времени
# Estimated font size: 6.0
# Estimated thickness: 2.7558579668348955
# Далее  в  окне Sign  Document будет  предоставлена  возможность  заполнить  дополнительные поля, отображаемые в свойствах ЭП (см. Рисунок 16). Для формирования ЭП следует нажать кнопку Sign .
# Estimated font size: 6.0
# Estimated thickness: 2.098336304218657
# Рисунок 16. Окно создания подписи
# Estimated font size: 6.0
# Estimated thickness: 2.44375
# Последним шагом следует указать файл в окне Save as , в который будет сохранена подписанная копия документа. Пример созданной в документе ЭП приведен на рисунке (см. Рисунок 17).
# Estimated font size: 5.0
# Estimated thickness: 1.2543859649122806
# Рисунок 17. Пример ЭП в документе
# Estimated font size: 6.0
# Estimated thickness: 2.736842105263158
# 3.5. Виды подписей в программах Adobe.
# Estimated font size: 7.0
# Estimated thickness: 1.5714285714285714
# Компания Adobe в своих продуктах разделяет подписи на ЭП (в документации Adobe такие подписи называются цифровыми) и подписи от руки.
# Estimated font size: 5.0
# Estimated thickness: 1.3452380952380953
# Подпись от руки представляет собой сделанную вручную пометку на странице, аналогичную рисунку произвольной формы, созданному при помощи инструмента "Карандаш". Подпись от руки не имеет никакого отношения к ЭП и не отображается на панели "Подписи".
# Estimated font size: 6.0
# Estimated thickness: 1.256578947368421
# Электронные подписи делятся на подписи для утверждения и сертифицирующие . Оба вида подписей позволяют утвердить содержимое файла PDF. Но сертифицирующая подпись обеспечивает  более  высокий  уровень  управления  документом.  С  ее  помощью  можно  указать допустимые типы изменений, при внесении которых документ останется сертифицированным.
# Estimated font size: 6.0
# Estimated thickness: 1.6441470609396358
# Предположим, что государственной службе необходимо создать форму с полями подписи.  Когда  форма  закончена,  служба  сертифицирует  документ,  позволяя  пользователям  изменять только поля формы и подписывать документ. Пользователи могут заполнять форму и подписывать  документ  подписью  для  утверждения.  Однако  при  удалении  страниц  и  добавлении комментариев документ утрачивает существующее сертифицированное состояние.
# Estimated font size: 6.0
# Estimated thickness: 1.3251376146788991
# Таблица 1. Виды подписей в программах Adobe.
# Estimated font size: 6.0
# Estimated thickness: 2.9702625102543068
# <table><tbody><tr><th>Вид подписи</th><th>Отображение в документе</th><th>Описание</th></tr><tr><td>Обычная подпись  (подпись для  утверждения)</td><td>Подпись отображается в виде  поля подписи в документе и  на панели "Подписи".</td><td>Может использоваться для много- кратного подписания документа PDF  несколькими людьми.</td></tr><tr><td>Сертифицирующая  подпись</td><td>Документ может быть серти- фицирован как с видимой, так  и без видимой подписи.  В первом случае подпись бу- дет отображаться в виде поля  подписи в документе и на па- нели "Подписи".  Во втором случае подпись бу- дет отображаться только на  панели "Подписи".</td><td>Удостоверяет документ PDF.  Может применяться только в том  случае, если документ PDF не со- держит других подписей.  Позволяет указывать типы изме- нений, разрешенных для доку- мента (добавление комментариев,  заполнение форм или добавление  обычных подписей) или запре- тить любые дальнейшие измене-</td></tr></tbody></table>
# 3.6. Отличия Adobe Reader и Adobe Acrobat при создании ЭП.
# Estimated font size: 7.0
# Estimated thickness: 1.5263157894736843
# Отличия в возможностях работы с электронной подписью в программах Adobe Reader и Adobe Acrobat обусловлены особенностями функционирования этих программ (такова политика их производителя - компании Adobe) и никак не связаны с работой модуля КриптоПро PDF.
# Estimated font size: 6.0
# Estimated thickness: 1.3
# Программа Adobe Acrobat позволяет:
# Estimated font size: 6.0
# Estimated thickness: 1.5714285714285714
# сертифицировать произвольный документ PDF (видимой подписью или без видимой подписи), в том числе на алгоритме ГОСТ Р 34.10-2001 с помощью КриптоПро PDF;
# Estimated font size: 6.0
# Estimated thickness: 1.328
# подписывать произвольный документ PDF (в том числе на алгоритме ГОСТ Р 34.10-2001 с помощью КриптоПро PDF);
# Estimated font size: 5.0
# Estimated thickness: 1.2916666666666665
# проверять ЭП (в том числе на алгоритме ГОСТ Р 34.10-2001 с помощью КриптоПро PDF) в произвольном документе PDF.
# Estimated font size: 6.0
# Estimated thickness: 1.40625
# Программа Adobe Reader позволяет:
# Estimated font size: 6.0
# Estimated thickness: 1.2941176470588236
# проверять ЭП (в том числе на алгоритме ГОСТ Р 34.10-2001 с помощью КриптоПро PDF) в произвольном документе PDF;
# Estimated font size: 5.0
# Estimated thickness: 1.2986257928118392
# подписывать документы PDF с расширенным доступом (в том числе на алгоритме ГОСТ Р 34.10-2001 с помощью КриптоПро PDF).
# Estimated font size: 6.0
# Estimated thickness: 1.3681318681318682
# К документам PDF с расширенным доступом относятся PDF-формы, предназначенные для заполнения пользователями в Adobe Reader или PDF-файлы, с которыми проведена операция расширения доступа. Операция расширения доступа или создания PDF-формы может быть осуществлена над произвольным документом PDF, при этом сам документ PDF может быть создан любым доступным способом.
# Estimated font size: 6.0
# Estimated thickness: 1.2272665163626426
# На настоящий момент такая операция доступна в программах Adobe Acrobat 8 Professional, Adobe Acrobat 9 Pro и Adobe Acrobat 9 Pro Extended, Adobe Acrobat Х, Adobe Acrobat ХI.
# Estimated font size: 6.0
# Estimated thickness: 1.3617669459253618
# Обратите  внимание,  что  в  программе  Adobe  Acrobat  9  Standard  операция  расширения доступа присутствует в усеченном виде и ее проведение не даст пользователям Adobe Reader возможности создания или добавления подписи.
# Estimated font size: 6.0
# Estimated thickness: 1.3082137161084528
# 3.7. Создание ЭП в Adobe Reader
# Estimated font size: 7.0
# Estimated thickness: 1.5702702702702704
# Для  того  чтобы  пользователь  получил  возможность  создания  ЭЦП  документа  в  Adobe Reader,  необходимо  сделать  с  данным  документом  ряд  предварительных  действий  в  Adobe Acrobat:
# Estimated font size: 6.0
# Estimated thickness: 1.3333333333333333
# Открыть документ в программе Adobe Acrobat;
# Estimated font size: 6.0
# Estimated thickness: 1.4
# Для Adobe Acrobat XI Pro - выбрать пункт меню Файл Сохранить как другой… Файл PDF Reader с расширенными возможностями Включить дополнительные инструменты (включая заполнение и сохранение форм) (см. Рисунок 18) и в появившемся окне нажать кнопку Сохранить сейчас
# Estimated font size: 5.0
# Estimated thickness: 1.825220680958386
# Рисунок 18. Разрешение дополнительных возможностей пользователя в Adobe Acrobat XI Pro
# Estimated font size: 5.0
# Estimated thickness: 2.508928571428571
# Для Adobe Acrobat X Pro - выбрать пункт меню Файл Сохранить как Файл PDF Reader  с  расширенными  возможностями Разрешить  дополнительные  функции… (см. Рисунок 19) и в появившемся окне нажать кнопку Сохранить сейчас.
# Estimated font size: 5.0
# Estimated thickness: 2.0898876404494384
# Рисунок 19. Разрешение дополнительных возможностей пользователя в Adobe Acrobat X Pro
# Estimated font size: 6.0
# Estimated thickness: 2.6607142857142856
# Для Adobe Acrobat Professional версии 9 - выбрать пункт меню Advanced Extend Features  in  Adobe  Reader (см.  Рисунок  20)  и  в  появившемся  окне  нажать  кнопку Save Now .
# Estimated font size: 6.0
# Estimated thickness: 1.8176272984441302
# Рисунок 20. Разрешение дополнительных возможностей пользователя в Adobe Acrobat Professional 9
# Estimated font size: 6.0
# Estimated thickness: 2.668103448275862
# Для Adobe Acrobat Professional версии 8 - выбрать пункт меню Advanced Enable Usage  Rights  in  Adobe  Reader (см.  Рисунок  21)  и  в  появившемся  окне  нажать  кнопку Save Now .
# Estimated font size: 6.0
# Estimated thickness: 2.25
# Рисунок 21. Разрешение дополнительных возможностей пользователя в Adobe Acrobat Professional версии 8
# Estimated font size: 6.0
# Estimated thickness: 2.615131578947368
# Сохранить документ.
# Estimated font size: 6.0
# Estimated thickness: 2.0
# После выполнения описанных действий в данном документе появится возможность создания ЭЦП в программе Adobe Reader. Процесс формирования ЭЦП описан в п.п. 3.3 настоящего Руководства.
# Estimated font size: 6.0
# Estimated thickness: 1.3333333333333333
# 3.8. Проверка ЭП
# Estimated font size: 9.0
# Estimated thickness: 1.6666666666666667
# По умолчанию при открытии документа проверяются все имеющиеся в нем ЭП.
# Estimated font size: 6.0
# Estimated thickness: 1.4134615384615383
# Чтобы просмотреть результат проверки отдельной ЭП, следует нажать на левую кнопку мыши  на  данной  электронной  подписи  в  документе.  В  результате  выбранная  подпись  будет подвергнута  проверке  и  появится  окно Signature  Validation  Status ( Результат  проверки подписи ) (см. Рисунок 22).
# Estimated font size: 6.0
# Estimated thickness: 1.5
# Рисунок 22. Результат проверки подписи
# Estimated font size: 6.0
# Estimated thickness: 2.8602278120550544
# Подпись может иметь один из следующих статусов (см. Таблица 2):
# Estimated font size: 6.0
# Estimated thickness: 1.3350071736011477
# ДЕЙСТВИТЕЛЬНА ,  если  с  момента  подписания,  подписанные  данные  не  были изменены.
# Estimated font size: 6.0
# Estimated thickness: 1.5520833333333333
# НЕДЕЙСТВИТЕЛЬНА , если с момента подписания, подписанные данные были изменены или повреждены.
# Estimated font size: 6.0
# Estimated thickness: 1.556122448979592
# НЕОПРЕДЕЛЕНА ,  если  по  каким-либо причинам не удалось проверить подпись, либо подписанные данные не были изменены, но сертификат подписавшего определен как недоверенный.
# Estimated font size: 6.0
# Estimated thickness: 1.5245098039215685
# Сертификат считается  доверенным,  если  одновременно  выполняются  следующие  усло-
# Estimated font size: 6.0
# Estimated thickness: 1.319672131147541
# 1. Сертификат имеет корректную ЭП центра сертификации, выдавшего сертификат.
# Estimated font size: 5.0
# Estimated thickness: 1.25
# 2. Сертификат актуален на текущую дату по сроку действия.
# Estimated font size: 6.0
# Estimated thickness: 1.3178428992543783
# 3. Сертификат  центра  сертификации,  выдавшего  сертификат,  установлен  в  хранилище (ROOT) доверенных корневых сертификатов Windows.
# Estimated font size: 6.0
# Estimated thickness: 1.288525367472736
# 4. Сертификат отсутствует в актуальном на текущую дату списке отозванных сертификатов.
# Estimated font size: 5.0
# Estimated thickness: 1.3570691434468525
# Таблица 2. Перечень статусов электронной подписи
# Estimated font size: 5.0
# Estimated thickness: 2.216666666666667
# <table><tbody><tr><th>Иконка</th><th>Статус</th><th>Описание</th></tr><tr><td></td><td>ДЕЙСТВИТЕЛЬНА</td><td>Подписанные данные не были изменены с момента подписания.</td></tr><tr><td></td><td>ДЕЙСТВИТЕЛЬНА</td><td>Подписанные данные не были изменены с момента подписания.  Однако в сам документ были внесены изменения.</td></tr><tr><td></td><td></td><td>НЕДЕЙСТВИТЕЛЬНА  Подписанные данные документа были изменены или повреждены  после подписания.</td></tr><tr><td></td><td>НЕОПРЕДЕЛЕНА</td><td>Подписанные данные не были изменены с момента подписания.  Однако сертификат подписавшего определен как недействите- лен.</td></tr><tr><td></td><td>НЕОПРЕДЕЛЕНА</td><td>Подписанные данные не были изменены с момента подписания,  но в сам документ были внесены изменения. И сертификат под- писавшего определен как недействителен.</td></tr><tr><td></td><td>НЕОПРЕДЕЛЕНА</td><td>На стадии проверки подписи возникли ошибки.</td></tr></tbody></table>
# Окно  с  параметрами  подписи  можно  вызвать  нажатием  кнопки Signature  Properties ( Параметры подписи )  в  окне Результат  проверки  подписи .  Либо  выделить  пункт Show Signature Properties в контекстном меню, вызываемом по нажатию правой кнопки на область ЭП в документе.
# Estimated font size: 6.0
# Estimated thickness: 2.0
# вия:
# Estimated font size: 5.0
# Estimated thickness: 2.5
# Рисунок 23. Параметры подписи
# Estimated font size: 6.0
# Estimated thickness: 2.5637560637560637
# 4. Перечень сокращений
# Estimated font size: 8.0
# Estimated thickness: 2.1714285714285713
# ДПМ
# Estimated font size: 7.0
# Estimated thickness: 1.2714285714285714
# Дополнительный программный модуль (plug-in)
# Estimated font size: 6.0
# Estimated thickness: 1.2835820895522387
# ПК
# Estimated font size: 7.0
# Estimated thickness: 1.3333333333333333
# Программный комплекс
# Estimated font size: 5.0
# Estimated thickness: 1.2777777777777777
# СКЗИ
# Estimated font size: 7.0
# Estimated thickness: 1.625
# Средство криптографической защиты информации
# Estimated font size: 6.0
# Estimated thickness: 1.4109589041095891
# ЭП
# Estimated font size: 7.5
# Estimated thickness: 1.3333333333333333
# Электронная подпись
# Estimated font size: 5.0
# Estimated thickness: 1.1935483870967742
# PDF
# Estimated font size: 7.0
# Estimated thickness: 2.125
# Portable Document Format, платформонезависимый формат электронных доку- ментов
# Estimated font size: 6.0
# Estimated thickness: 1.3333333333333333
# TSP
# Estimated font size: 7.0
# Estimated thickness: 1.3333333333333333
# Time-Stamp Protocol
# Estimated font size: 6.0
# Estimated thickness: 1.2592592592592593
# 5. Перечень рисунков
# Estimated font size: 9.0
# Estimated thickness: 1.6666666666666667
# <table><tbody><tr><td>Рисунок 1. Мастер установки «КриптоПро PDF» ............................................................ 5</td></tr><tr><td>Рисунок 2. Лицензионное соглашение на использование «КриптоПро PDF» .................... 6</td></tr><tr><td>Рисунок 3. Сведения о пользователе «КриптоПро PDF»................................................. 6</td></tr><tr><td>Рисунок 4. Вид установки «КриптоПро PDF» ................................................................. 7</td></tr><tr><td>Рисунок 5. Выборочная установка «КриптоПро PDF» .................................................... 8</td></tr><tr><td>Рисунок 6. Окно подтверждения установки «КриптоПро PDF» ....................................... 8</td></tr><tr><td>Рисунок 7. Завершение работы мастера установки ....................................................... 9</td></tr><tr><td>Рисунок 8. Настройка формирования и проверки ЭП .................................................. 10</td></tr><tr><td>Рисунок 9. Настройки формирования ЭП .................................................................... 11</td></tr><tr><td>Рисунок 10. Панель настройки .................................................................................. 12</td></tr><tr><td>Рисунок 11. Ввод серийного номера лицензии КриптоПро PDF ..................................... 12</td></tr><tr><td>Рисунок 12. Добавление ЭП ...................................................................................... 13</td></tr><tr><td>Рисунок 13. Выбор метода создания ЭП ..................................................................... 13</td></tr><tr><td>Рисунок 14. Выбор сертификата для формирования ЭП .............................................. 14</td></tr><tr><td>Рисунок 15. Выбор и редактирование служб штампов времени .................................... 15</td></tr><tr><td>Рисунок 16. Окно создания подписи .......................................................................... 16</td></tr><tr><td>Рисунок 17. Пример ЭП в документе .......................................................................... 16</td></tr><tr><td>Рисунок 18. Разрешение дополнительных возможностей пользователя в Adobe Acrobat XI  Pro ......................................................................................................... 18</td></tr><tr><td>Рисунок 19. Разрешение дополнительных возможностей пользователя в Adobe Acrobat X  Pro ......................................................................................................... 19</td></tr><tr><td>Рисунок  20.  Разрешение  дополнительных  возможностей  пользователя  в  Adobe  Acrobat  Professional 9 .......................................................................................... 19</td></tr><tr><td>Рисунок  21.  Разрешение  дополнительных  возможностей  пользователя  в  Adobe  Acrobat  Professional версии 8 ............................................................................... 20</td></tr><tr><td>Рисунок 22. Результат проверки подписи ................................................................... 20</td></tr><tr><td>Рисунок 23. Параметры подписи ................................................................................ 22</td></tr></tbody></table>
# 6. Перечень таблиц
# Estimated font size: 9.0
# Estimated thickness: 2.0
# <table><tbody><tr><td>Таблица 1. Виды подписей в программах Adobe. ........................................................ 17</td></tr><tr><td>Таблица 2. Перечень статусов электронной подписи................................................... 21</td></tr></tbody></table>

# %%
import json

with open("annotations.json", "w") as f:
    json.dump(annotations, f)

# %% [markdown]
# # Postprocessing

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from collections import defaultdict
import json


def header_clusters(headers_info):
    # Extract features
    data = np.array([[item['fontsize'], item['thickness']] for item in headers_info])

    # Standardize the data
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data)

    # DBSCAN
    dbscan = DBSCAN(eps=0.5, min_samples=2)
    labels = dbscan.fit_predict(data_scaled)

    # Assign cluster labels to headers
    for i, item in enumerate(headers_info):
        item['cluster'] = labels[i]

    # Assign cluster labels to headers
    for i, item in enumerate(headers_info):
        item['cluster'] = labels[i]

    # Group headers by clusters and compute mean values
    clusters = defaultdict(list)
    for item in headers_info:
        if item['cluster'] != -1:
            clusters[item['cluster']].append(item)

    cluster_stats = []
    for cluster_id, items in clusters.items():
        mean_fontsize = np.mean([item['fontsize'] for item in items])
        mean_thickness = np.mean([item['thickness'] for item in items])
        cluster_stats.append({
            'cluster_id': cluster_id,
            'mean_fontsize': mean_fontsize,
            'mean_thickness': mean_thickness,
            'items': items
        })

    # Sort clusters based on mean fontsize and thickness
    cluster_stats_sorted = sorted(
        cluster_stats,
        key=lambda x: (x['mean_fontsize'], x['mean_thickness']),
        reverse=True
    )
    return cluster_stats_sorted


def convert_annotations_to_markdown(annotations):
    # Parse the JSON annotations
    items = annotations

    # Collect font sizes and thicknesses of headers
    headers_info = []
    for item in items:
        if item.get('type') == 'h':
            headers_info.append({
                'id': item['id'],
                'fontsize': item.get('fontsize', 0),
                'thickness': item.get('thickness', 0),
            })
    # Headers clustering
    cluster_stats_sorted = header_clusters(headers_info)
    # Map clusters order to MD level
    header_level_map = {
        idx: i + 1 for i, stat in enumerate(cluster_stats_sorted)
        for idx in [item['id'] for item in stat['items']]
    }
    # Build the Markdown text
    markdown_lines = []
    for item in items:
        item_type = item['type']
        if item_type == 'h':
            # Get the header level
            header_level = header_level_map.get(item['id'], 1)
            print(header_level)
            prefix = '#' * header_level  # Markdown header prefix
            markdown_lines.append(f"{prefix} {item.get('text', '')}")
            print(f"{prefix} {item.get('text', '')}")
        elif item_type == 'p':
            markdown_lines.append(item.get('text', ''))
        elif item_type == 'li':
            markdown_lines.append(f"- {item.get('text', '')}")
        elif item_type == 'img':
            src = item.get('src', '')
            markdown_lines.append(f"![Image]({src})")
        elif item_type == 'table':
            html = item.get('html', '')
            # Include HTML directly
            markdown_lines.append(html)
        else:
            # If  type is unrecognized, skip it
            pass
        # Add empty line after each item for Markdown formatting
        markdown_lines.append('')

    # Join all lines into the final Markdown text
    markdown_text = '\n'.join(markdown_lines)
    return markdown_text


# Load the annotations from JSON
with open('annotations.json') as f:
    annotations = json.loads(f.read())

# Convert annotations to Markdown

markdown_text = convert_annotations_to_markdown(annotations)

# print(markdown_text)

# %%
with open('./manual_annotations.md', 'w') as f:
    f.write(markdown_text)

# %%
# with open('./result.md', 'w', encoding='utf-16') as f:
#     f.write(conv_result.document.export_to_markdown())

# %%
# import shutil

# shutil.rmtree(pages_dir)

# %%
# %%time
# !docling tuo.pdf --to md
# Out:
# Fetching 9 files: 100% 9/9 [00:00<00:00, 107240.73it/s]
# CPU times: user 403 ms, sys: 48.5 ms, total: 452 ms
# Wall time: 1min 10s

# %% [markdown]
# ## Libre-office

# %%
# !apt-get install libreoffice
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common firebird3.0-common
#   firebird3.0-common-doc firebird3.0-server-core firebird3.0-utils fonts-crosextra-caladea
#   fonts-crosextra-carlito fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3
#   hunspell-en-us libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5 libcolamd2 libe-book-0.1-1
#   libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfbclient2 libfontenc1 libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgudev-1.0-0 libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0
#   libhyphen0 libib-util libjsp-api-java liblangtag-common liblangtag1 liblibreoffice-java libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0 libreoffice-base
#   libreoffice-base-core libreoffice-base-drivers libreoffice-calc libreoffice-common
#   libreoffice-core libreoffice-draw libreoffice-gnome libreoffice-gtk3 libreoffice-impress
#   libreoffice-java-common libreoffice-math libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh libreoffice-script-provider-js
#   libreoffice-script-provider-python libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb
#   libreoffice-sdbc-mysql libreoffice-sdbc-postgresql libreoffice-style-colibre
#   libreoffice-style-elementary libreoffice-style-yaru libreoffice-wiki-publisher libreoffice-writer
#   librevenge-0.0-0 libservlet-api-java libservlet3.1-java libsuitesparseconfig5 libtext-iconv-perl
#   libtommath1 libuno-cppu3 libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoloader-java libvisio-0.1-1 libwebsocket-api-java libwpd-0.10-10
#   libwpg-0.3-3 libwps-0.4-4 libxkbfile1 libxmlsec1 libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2
#   lp-solve openjdk-11-jre poppler-data python3-uno uno-libs-private ure ure-java x11-utils
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist firebird3.0-server
#   firebird3.0-doc hunspell openoffice.org-hunspell | openoffice.org-core java-virtual-machine
#   libhsqldb1.8.0-java-gcj raptor2-utils rasqal-utils librdf-storage-postgresql librdf-storage-mysql
#   librdf-storage-sqlite librdf-storage-virtuoso redland-utils cups-bsd firefox | firefox-esr
#   | thunderbird ghostscript gpa hyphen-hyphenation-patterns imagemagick
#   | graphicsmagick-imagemagick-compat libreoffice-grammarcheck libreoffice-help libreoffice-l10n
#   libreoffice-librelogo myspell-dictionary mythes-thesaurus openclipart-libreoffice pstoedit
#   unixodbc gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-plugins-ugly
#   gstreamer1.0-plugins-bad gstreamer1.0-libav libsane1 libofficebean-java libjtds-java
#   libsqliteodbc | tdsodbc | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data bluez
#   default-mysql-server | virtual-mysql-server postgresql mediawiki poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum mesa-utils
# The following NEW packages will be installed:
#   apparmor default-jre default-jre-headless dictionaries-common firebird3.0-common
#   firebird3.0-common-doc firebird3.0-server-core firebird3.0-utils fonts-crosextra-caladea
#   fonts-crosextra-carlito fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic gstreamer1.0-gl gstreamer1.0-gtk3
#   hunspell-en-us libabsl20210324 libabw-0.1-1 libatk-wrapper-java libatk-wrapper-java-jni
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5 libcolamd2 libe-book-0.1-1
#   libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfbclient2 libfontenc1 libfreehand-0.1-1 libgpgme11 libgpgmepp6 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgudev-1.0-0 libharfbuzz-icu0 libhsqldb1.8.0-java libhunspell-1.7-0
#   libhyphen0 libib-util libjsp-api-java liblangtag-common liblangtag1 liblibreoffice-java libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0 libreoffice
#   libreoffice-base libreoffice-base-core libreoffice-base-drivers libreoffice-calc
#   libreoffice-common libreoffice-core libreoffice-draw libreoffice-gnome libreoffice-gtk3
#   libreoffice-impress libreoffice-java-common libreoffice-math libreoffice-nlpsolver
#   libreoffice-report-builder libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python libreoffice-sdbc-firebird
#   libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql libreoffice-sdbc-postgresql
#   libreoffice-style-colibre libreoffice-style-elementary libreoffice-style-yaru
#   libreoffice-wiki-publisher libreoffice-writer librevenge-0.0-0 libservlet-api-java
#   libservlet3.1-java libsuitesparseconfig5 libtext-iconv-perl libtommath1 libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3
#   libunoloader-java libvisio-0.1-1 libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4
#   libxkbfile1 libxmlsec1 libxmlsec1-nss libxtst6 libxxf86dga1 libyajl2 lp-solve openjdk-11-jre
#   poppler-data python3-uno uno-libs-private ure ure-java x11-utils
# 0 upgraded, 128 newly installed, 0 to remove and 49 not upgraded.
# Need to get 227 MB of archives.
# After this operation, 855 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-opensymbol all 2:102.12+LibO7.3.7-0ubuntu0.22.04.7 [103 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-colibre all 1:7.3.7-0ubuntu0.22.04.7 [1,294 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-sal3 amd64 1:7.3.7-0ubuntu0.22.04.7 [197 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.7 [17.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppu3 amd64 1:7.3.7-0ubuntu0.22.04.7 [87.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 uno-libs-private amd64 1:7.3.7-0ubuntu0.22.04.7 [232 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag-common all 0.6.3-2ubuntu1 [193 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag1 amd64 0.6.3-2ubuntu1 [53.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.7 [343 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.7 [15.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure amd64 1:7.3.7-0ubuntu0.22.04.7 [1,312 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-common all 1:7.3.7-0ubuntu0.22.04.7 [23.4 MB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabsl20210324 amd64 0~20210324.2-2 [387 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [530 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [96.7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libeot0 amd64 0.01-5build2 [28.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-data all 3.4.5-1build2 [179 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1build2 [13.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.2 [136 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgmepp6 amd64 1.16.0-1.2ubuntu4.2 [109 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.1 [5,886 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmythes-1.2-0 amd64 2:1.2.4-4build1 [9,352 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-parser-0.17-0 amd64 0.17.2-2 [107 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-0.17-0 amd64 0.17.2-2 [393 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4 [172 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmhash2 amd64 0.9.9.9-9build2 [95.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 librasqal3 amd64 0.9.33-0.2ubuntu1 [193 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 librdf0 amd64 1.0.17-1.1ubuntu3 [106 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu7 [209 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-nss amd64 1.2.33-1build2 [67.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-core amd64 1:7.3.7-0ubuntu0.22.04.7 [40.4 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.7 [974 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base-drivers amd64 1:7.3.7-0ubuntu0.22.04.7 [602 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-base amd64 1:7.3.7-0ubuntu0.22.04.7 [1,725 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.25+9-1ubuntu1~22.04 [216 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common-doc all 3.0.8.33535.ds4-1ubuntu2 [26.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-common all 3.0.8.33535.ds4-1ubuntu2 [15.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtommath1 amd64 1.2.0-6ubuntu0.22.04.1 [56.5 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfbclient2 amd64 3.0.8.33535.ds4-1ubuntu2 [512 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libib-util amd64 3.0.8.33535.ds4-1ubuntu2 [3,378 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-server-core amd64 3.0.8.33535.ds4-1ubuntu2 [2,533 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 firebird3.0-utils amd64 3.0.8.33535.ds4-1ubuntu2 [872 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-dejavu all 2.37-2build1 [3,192 B]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation2 all 2.1.5-1 [1,614 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-linuxlibertine all 5.3.0-6 [1,627 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-noto-extra all 20201225-1build1 [72.4 MB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-ui-core all 20201225-1build1 [1,420 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium all 20081126:1.03-4 [245 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium-basic all 1.102-1.1 [384 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphene-1.0-0 amd64 1.10.8-1 [48.2 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.2 [204 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gl amd64 1.20.1-1ubuntu0.2 [125 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-gtk3 amd64 1.20.3-0ubuntu1.1 [33.2 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbsh-java all 2.0b4-20 [289 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdr-0.1-1 amd64 0.1.6-2build2 [392 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libel-api-java all 3.0.0-3 [64.9 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 libetonyek-0.1-1 amd64 0.1.10-3build1 [637 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfreehand-0.1-1 amd64 0.1.2-3build2 [272 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet-api-java all 4.0.1-2 [81.0 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjsp-api-java all 2.3.4-3 [53.7 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwebsocket-api-java all 1.1-2 [40.1 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libservlet3.1-java all 1:4.0.1-2 [9,276 B]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhsqldb1.8.0-java all 1.8.0.10+dfsg-11 [765 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunoloader-java all 1:7.3.7-0ubuntu0.22.04.7 [13.0 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure-java amd64 1:7.3.7-0ubuntu0.22.04.7 [83.4 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liblibreoffice-java all 1:7.3.7-0ubuntu0.22.04.7 [1,604 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmspub-0.1-1 amd64 0.1.4-3build3 [144 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmwaw-0.3-3 amd64 0.3.21-1build1 [2,375 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libodfgen-0.1-1 amd64 0.1.8-2build2 [245 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpagemaker-0.0-0 amd64 0.0.4-1build3 [55.9 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/main amd64 lp-solve amd64 5.5.2.5-2build2 [315 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-calc amd64 1:7.3.7-0ubuntu0.22.04.7 [8,426 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisio-0.1-1 amd64 0.1.7-1build5 [238 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpd-0.10-10 amd64 0.10.3-2build1 [209 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpg-0.3-3 amd64 0.3.3-1build3 [49.9 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-draw amd64 1:7.3.7-0ubuntu0.22.04.7 [3,228 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-impress amd64 1:7.3.7-0ubuntu0.22.04.7 [1,359 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.7 [597 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder-bin amd64 1:7.3.7-0ubuntu0.22.04.7 [971 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.7 [10.3 MB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-uno amd64 1:7.3.7-0ubuntu0.22.04.7 [148 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice amd64 1:7.3.7-0ubuntu0.22.04.7 [12.9 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gnome amd64 1:7.3.7-0ubuntu0.22.04.7 [72.9 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-gtk3 amd64 1:7.3.7-0ubuntu0.22.04.7 [509 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-java-common all 1:7.3.7-0ubuntu0.22.04.7 [621 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-report-builder all 1:7.3.7-0ubuntu0.22.04.7 [2,112 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-bsh all 1:7.3.7-0ubuntu0.22.04.7 [42.3 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-js all 1:7.3.7-0ubuntu0.22.04.7 [645 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-script-provider-python all 1:7.3.7-0ubuntu0.22.04.7 [16.5 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-firebird amd64 1:7.3.7-0ubuntu0.22.04.7 [176 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-hsqldb amd64 1:7.3.7-0ubuntu0.22.04.7 [135 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-mysql amd64 1:7.3.7-0ubuntu0.22.04.7 [123 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-sdbc-postgresql amd64 1:7.3.7-0ubuntu0.22.04.7 [279 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-elementary all 1:7.3.7-0ubuntu0.22.04.7 [8,020 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-yaru all 1:7.3.7-0ubuntu0.22.04.7 [3,761 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libreoffice-wiki-publisher all 1.2.0+LibO7.3.7-0ubuntu0.22.04.7 [7,932 B]
# Get:128 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-nlpsolver all 0.9+LibO7.3.7-0ubuntu0.22.04.7 [7,988 B]
# Fetched 227 MB in 8s (28.2 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 123857 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../002-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../003-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../004-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../005-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../006-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../007-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../008-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../009-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../010-ure_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../011-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../012-libabsl20210324_0~20210324.2-2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../013-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../014-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../015-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../016-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../017-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../018-libgpgme11_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../019-libgpgmepp6_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../020-libharfbuzz-icu0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../021-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../022-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../023-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../024-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../025-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../026-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../027-libraptor2-0_2.0.15-0ubuntu4_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../028-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../029-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../030-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../031-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../032-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../033-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../034-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../035-libreoffice-base-core_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-base-drivers.
# Preparing to unpack .../036-libreoffice-base-drivers_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-base.
# Preparing to unpack .../037-libreoffice-base_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/dialog.xlc to /usr/lib/libreoffice/share/basic/dialog.xlc.noaccess by libreoffice-base', none removed.
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/script.xlc to /usr/lib/libreoffice/share/basic/script.xlc.noaccess by libreoffice-base', none removed.
# Unpacking libreoffice-base (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../038-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../039-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../040-apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../041-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../042-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../043-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../044-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../045-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package firebird3.0-common-doc.
# Preparing to unpack .../046-firebird3.0-common-doc_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-common.
# Preparing to unpack .../047-firebird3.0-common_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libtommath1:amd64.
# Preparing to unpack .../048-libtommath1_1.2.0-6ubuntu0.22.04.1_amd64.deb ...
# Unpacking libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Selecting previously unselected package libfbclient2:amd64.
# Preparing to unpack .../049-libfbclient2_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libib-util:amd64.
# Preparing to unpack .../050-libib-util_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-server-core:amd64.
# Preparing to unpack .../051-firebird3.0-server-core_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-utils.
# Preparing to unpack .../052-firebird3.0-utils_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../053-fonts-crosextra-caladea_20130214-2.1_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2.1) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../054-fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../055-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../056-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../057-fonts-dejavu_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu (2.37-2build1) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../058-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../059-fonts-linuxlibertine_5.3.0-6_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-6) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../060-fonts-noto-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-core (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-extra.
# Preparing to unpack .../061-fonts-noto-extra_20201225-1build1_all.deb ...
# Unpacking fonts-noto-extra (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../062-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-ui-core.
# Preparing to unpack .../063-fonts-noto-ui-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-ui-core (20201225-1build1) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../064-fonts-sil-gentium_20081126%3a1.03-4_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-4) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../065-fonts-sil-gentium-basic_1.102-1.1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1.1) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../066-libgraphene-1.0-0_1.10.8-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../067-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../068-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.2_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.2) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../069-gstreamer1.0-gl_1.20.1-1ubuntu0.2_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.2) ...
# Selecting previously unselected package gstreamer1.0-gtk3:amd64.
# Preparing to unpack .../070-gstreamer1.0-gtk3_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../071-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../072-libabw-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../073-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../074-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../075-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../076-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../077-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../078-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libbsh-java.
# Preparing to unpack .../079-libbsh-java_2.0b4-20_all.deb ...
# Unpacking libbsh-java (2.0b4-20) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../080-libcdr-0.1-1_0.1.6-2build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../081-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../082-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../083-libe-book-0.1-1_0.1.3-2build2_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Selecting previously unselected package libel-api-java.
# Preparing to unpack .../084-libel-api-java_3.0.0-3_all.deb ...
# Unpacking libel-api-java (3.0.0-3) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../085-libepubgen-0.1-1_0.1.1-1ubuntu5_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../086-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../087-libfreehand-0.1-1_0.1.2-3build2_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-3build2) ...
# Selecting previously unselected package libservlet-api-java.
# Preparing to unpack .../088-libservlet-api-java_4.0.1-2_all.deb ...
# Unpacking libservlet-api-java (4.0.1-2) ...
# Selecting previously unselected package libjsp-api-java.
# Preparing to unpack .../089-libjsp-api-java_2.3.4-3_all.deb ...
# Unpacking libjsp-api-java (2.3.4-3) ...
# Selecting previously unselected package libwebsocket-api-java.
# Preparing to unpack .../090-libwebsocket-api-java_1.1-2_all.deb ...
# Unpacking libwebsocket-api-java (1.1-2) ...
# Selecting previously unselected package libservlet3.1-java.
# Preparing to unpack .../091-libservlet3.1-java_1%3a4.0.1-2_all.deb ...
# Unpacking libservlet3.1-java (1:4.0.1-2) ...
# Selecting previously unselected package libhsqldb1.8.0-java.
# Preparing to unpack .../092-libhsqldb1.8.0-java_1.8.0.10+dfsg-11_all.deb ...
# Unpacking libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Selecting previously unselected package libunoloader-java.
# Preparing to unpack .../093-libunoloader-java_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libunoloader-java (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package ure-java.
# Preparing to unpack .../094-ure-java_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking ure-java (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package liblibreoffice-java.
# Preparing to unpack .../095-liblibreoffice-java_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../096-libmspub-0.1-1_0.1.4-3build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../097-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../098-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../099-libpagemaker-0.0-0_0.0.4-1build3_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../100-lp-solve_5.5.2.5-2build2_amd64.deb ...
# Unpacking lp-solve (5.5.2.5-2build2) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../101-libwps-0.4-4_0.4.12-2build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../102-libreoffice-calc_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-calc (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../103-libvisio-0.1-1_0.1.7-1build5_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../104-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../105-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../106-libreoffice-draw_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-draw (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../107-libreoffice-impress_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-impress (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../108-libreoffice-math_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-math (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-report-builder-bin.
# Preparing to unpack .../109-libreoffice-report-builder-bin_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../110-libreoffice-writer_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-writer (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../111-python3-uno_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice.
# Preparing to unpack .../112-libreoffice_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-gnome.
# Preparing to unpack .../113-libreoffice-gnome_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-gtk3.
# Preparing to unpack .../114-libreoffice-gtk3_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-java-common.
# Preparing to unpack .../115-libreoffice-java-common_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-report-builder.
# Preparing to unpack .../116-libreoffice-report-builder_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-script-provider-bsh.
# Preparing to unpack .../117-libreoffice-script-provider-bsh_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-script-provider-js.
# Preparing to unpack .../118-libreoffice-script-provider-js_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-script-provider-python.
# Preparing to unpack .../119-libreoffice-script-provider-python_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-sdbc-firebird.
# Preparing to unpack .../120-libreoffice-sdbc-firebird_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-sdbc-hsqldb.
# Preparing to unpack .../121-libreoffice-sdbc-hsqldb_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-sdbc-mysql.
# Preparing to unpack .../122-libreoffice-sdbc-mysql_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-sdbc-postgresql.
# Preparing to unpack .../123-libreoffice-sdbc-postgresql_1%3a7.3.7-0ubuntu0.22.04.7_amd64.deb ...
# Unpacking libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-style-elementary.
# Preparing to unpack .../124-libreoffice-style-elementary_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-style-yaru.
# Preparing to unpack .../125-libreoffice-style-yaru_1%3a7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-wiki-publisher.
# Preparing to unpack .../126-libreoffice-wiki-publisher_1.2.0+LibO7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.7) ...
# Selecting previously unselected package libreoffice-nlpsolver.
# Preparing to unpack .../127-libreoffice-nlpsolver_0.9+LibO7.3.7-0ubuntu0.22.04.7_all.deb ...
# Unpacking libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.7) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up fonts-sil-gentium-basic (1.102-1.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Setting up fonts-noto-extra (20201225-1build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libel-api-java (3.0.0-3) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Setting up firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up fonts-sil-gentium (20081126:1.03-4) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up libwebsocket-api-java (1.1-2) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libfreehand-0.1-1 (0.1.2-3build2) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2) ...
# Setting up fonts-linuxlibertine (5.3.0-6) ...
# Setting up libbsh-java (2.0b4-20) ...
# Setting up libjsp-api-java (2.3.4-3) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up libservlet-api-java (4.0.1-2) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up fonts-crosextra-caladea (20130214-2.1) ...
# Setting up libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libunoloader-java (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up fonts-noto-ui-core (20201225-1build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up fonts-noto-core (20201225-1build1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.7) ...
# Setting up libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Setting up libservlet3.1-java (1:4.0.1-2) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Setting up libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up fonts-dejavu (2.37-2build1) ...
# Setting up libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Setting up lp-solve (5.5.2.5-2build2) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.2) ...
# Setting up firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.2) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up ure-java (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-math (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/math.xcd with new version
# Setting up libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/postgresql.xcd with new version
# Setting up liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-draw (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/draw.xcd with new version
#
# Creating config file /etc/libreoffice/registry/graphicfilter.xcd with new version
# Setting up libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/gnome.xcd with new version
# Setting up libreoffice-impress (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/impress.xcd with new version
#
# Creating config file /etc/libreoffice/registry/ogltrans.xcd with new version
# Setting up libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Setting up libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-calc (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/calc.xcd with new version
# Setting up libreoffice-base (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/base.xcd with new version
# Setting up libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-writer (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/writer.xcd with new version
# Setting up libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice (1:7.3.7-0ubuntu0.22.04.7) ...
# Setting up libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.7) ...
#
# Creating config file /etc/libreoffice/registry/reportbuilder.xcd with new version
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for dictionaries-common (1.28.14) ...

# %%
# !soffice --headless --convert-to html:HTML st6.docx
# Out:
# convert /content/st6.docx -> /content/st6.html using filter : HTML
